# %% [markdown]
# <a href="https://www.kaggle.com/code/basirajafarova/mental-health-analysis?scriptVersionId=142904966" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/kaggle/input/student-mental-health/Student Mental health.csv')

# %%
data.head(10)

# %%
data.shape

# %%
data.describe()# to get the statistics summary of the data

# %%
data.isna().sum() #for finding null values

# %%
data.columns #for finding column names

# %%
data = data.drop('Timestamp',axis=1)#i dont need timestamp

# %%
data.Age.value_counts().plot(kind='bar',color='cyan',figsize=(5,3))# to get bar chart of age distribution

# %% [markdown]
# **They do not have panic attac**

# %%
data['Do you have Panic attack?'].value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True)

# %% [markdown]
# **They do not have anxiety**

# %%
data['Do you have Anxiety?'].value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True, colors=([ 'rosybrown', 'black']))

# %% [markdown]
# **They ndo not have depression**

# %%
data['Do you have Depression?'].value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True, colors=(['olivedrab', 'pink']))

# %%
data['Choose your gender'].value_counts().plot(kind='bar',color='magenta',figsize=(3,3))# to get bar chart of gender distribution

# %%
data['What is your CGPA?'].value_counts()

# %%
data['What is your CGPA?'] = data['What is your CGPA?'].replace('3.50 - 4.00 ', '3.50 - 4.00')
data['What is your CGPA?'].value_counts()

# %%
data['What is your CGPA?'].value_counts().plot(kind='bar',color='mediumseagreen',figsize=(5,3))#to get gpa distribution of students

# %%
data['Your current year of Study'].unique()

# %%
data['Your current year of Study'].value_counts()

# %%
data['Your current year of Study'] = data['Your current year of Study'].replace('Year 1', 'year 1')
data['Your current year of Study'].value_counts()

# %%
data['Your current year of Study'] = data['Your current year of Study'].replace('Year 2', 'year 2')
data['Your current year of Study'].value_counts()#replacing same datas

# %%
data['Your current year of Study'] = data['Your current year of Study'].replace('Year 3', 'year 3')
data['Your current year of Study'].value_counts()#replacing same datas

# %%
data['Your current year of Study'].value_counts().plot(kind='bar',color='aquamarine',figsize=(4,3))

# %%
data['What is your course?'].value_counts().plot(kind='bar',color='y',figsize=(9,3))

# %% [markdown]
# **Most people are women**

# %%
gender = data.groupby(['Choose your gender']).size().plot(kind='pie',radius=1, center=(3, 3), autopct='%1.1f%%', shadow=True, colors=(['aquamarine', 'saddlebrown']))
gender

# %% [markdown]
# **Most People are single**

# %%
data['Marital status'].value_counts().plot(kind='pie',radius=1, center=(3, 3), autopct='%1.1f%%', shadow=True, colors=(['olivedrab', 'rosybrown']))

# %%
data.set_index('Choose your gender',inplace=True)

# %%
a=data.loc['Female'].head(10)

# %%
a

# %%
x=data[data['Marital status'] =='Yes']
x

# %%
x['Do you have Depression?'].value_counts

# %% [markdown]
# **All married people have depression(**

# %%
data
