# %% [markdown]
# <a href="https://www.kaggle.com/code/basirajafarova/analysing-by-indexing?scriptVersionId=142334420" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/gender-statistics/P_Data_Extract_From_Gender_Statistics(4)/f4bc7e60-3002-4965-b634-58394c135c0c_Series - Metadata.csv
# /kaggle/input/gender-statistics/P_Data_Extract_From_Gender_Statistics(4)/f4bc7e60-3002-4965-b634-58394c135c0c_Data.csv
# /kaggle/input/gender-statistics/P_Data_Extract_From_Gender_Statistics/1b582265-9e0a-4fd5-8345-4828993b72ba_Series - Metadata.csv
# /kaggle/input/gender-statistics/P_Data_Extract_From_Gender_Statistics/1b582265-9e0a-4fd5-8345-4828993b72ba_Data.csv
# /kaggle/input/gender-statistics/P_Data_Extract_From_Gender_Statistics(1)/97e9da70-c99c-4856-86c3-230b49992bc2_Series - Metadata.csv
# /kaggle/input/gender-statistics/P_Data_Extract_From_Gender_Statistics(1)/97e9da70-c99c-4856-86c3-230b49992bc2_Data.csv
# /kaggle/input/gender-statistics/P_Data_Extract_From_Gender_Statistics(3)/09151171-d67e-419b-b3a3-736f030958b8_Series - Metadata.csv
# ...

# %%
import pandas as pd

# %%
data=pd.read_csv('/kaggle/input/gender-statistics/P_Data_Extract_From_Gender_Statistics/1b582265-9e0a-4fd5-8345-4828993b72ba_Data.csv')

# %%
data.head(5)
# Out:
#                                          Series Name     Series Code  \
# 0  A woman can open a bank account in the same wa...  SG.OPN.BANK.EQ
# 1  A woman can open a bank account in the same wa...  SG.OPN.BANK.EQ
# 2  A woman can open a bank account in the same wa...  SG.OPN.BANK.EQ
# 3  A woman can open a bank account in the same wa...  SG.OPN.BANK.EQ
# 4  A woman can open a bank account in the same wa...  SG.OPN.BANK.EQ
#
#      Country Name Country Code 2003 [YR2003] 2004 [YR2004] 2005 [YR2005]  \
# 0     Afghanistan          AFG             1             1             1
# 1         Albania          ALB             1             1             1
# 2         Algeria          DZA             1             1             1
# 3  American Samoa          ASM            ..            ..            ..
# 4         Andorra          AND            ..            ..            ..
#
#   2006 [YR2006] 2007 [YR2007] 2008 [YR2008]  ... 2013 [YR2013] 2014 [YR2014]  \
# ...

# %%
data.shape
# Out:
# (89840, 24)

# %%
data.columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]',
#        '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# Series Name      3
# Series Code      5
# Country Name     5
# Country Code     5
# 2003 [YR2003]    5
# 2004 [YR2004]    5
# 2005 [YR2005]    5
# 2006 [YR2006]    5
# 2007 [YR2007]    5
# 2008 [YR2008]    5
# 2009 [YR2009]    5
# 2010 [YR2010]    5
# 2011 [YR2011]    5
# 2012 [YR2012]    5
# 2013 [YR2013]    5
# 2014 [YR2014]    5
# 2015 [YR2015]    5
# 2016 [YR2016]    5
# 2017 [YR2017]    5
# 2018 [YR2018]    5
# 2019 [YR2019]    5
# 2020 [YR2020]    5
# 2021 [YR2021]    5
# 2022 [YR2022]    5
# dtype: int64

# %%
data=data.drop(['2003 [YR2003]','2004 [YR2004]','2005 [YR2005]','2006 [YR2006]','2007 [YR2007]','2008 [YR2008]','2009 [YR2009]','2010 [YR2010]','2011 [YR2011]','2012 [YR2012]','2013 [YR2013]','2014 [YR2014]','2015 [YR2015]','2016 [YR2016]','2017 [YR2017]','2018 [YR2018]','2019 [YR2019]','2020 [YR2020]','2021 [YR2021]'],axis=1)

# %%
data.shape
# Out:
# (89840, 5)

# %%
data.isna().sum()
# Out:
# Series Name      3
# Series Code      5
# Country Name     5
# Country Code     5
# 2022 [YR2022]    5
# dtype: int64

# %%
data=data.dropna(subset=['Series Name'])

# %%
data=data.dropna(subset=['Series Code'])

# %%
data=data.dropna(subset=['Country Name'])

# %%
data=data.dropna(subset=['Country Code'])

# %%
data=data.dropna(subset=['2022 [YR2022]'])

# %%
data.isna().sum()
# Out:
# Series Name      0
# Series Code      0
# Country Name     0
# Country Code     0
# 2022 [YR2022]    0
# dtype: int64

# %%
data.describe()
# Out:
#                                               Series Name     Series Code  \
# count                                               89835           89835
# unique                                                339             339
# top     A woman can open a bank account in the same wa...  SG.OPN.BANK.EQ
# freq                                                  265             265
#
#        Country Name Country Code 2022 [YR2022]
# count         89835        89835         89835
# unique          265          265            17
# top     Afghanistan          AFG            ..
# freq            339          339         88500

# %%
data.set_index('Country Name',inplace=True)

# %%
data
# Out:
#                                                                                   Series Name  \
# Country Name
# Afghanistan                                 A woman can open a bank account in the same wa...
# Albania                                     A woman can open a bank account in the same wa...
# Algeria                                     A woman can open a bank account in the same wa...
# American Samoa                              A woman can open a bank account in the same wa...
# Andorra                                     A woman can open a bank account in the same wa...
# ...                                                                                       ...
# Sub-Saharan Africa                          Worried about not having enough money for old ...
# Sub-Saharan Africa (excluding high income)  Worried about not having enough money for old ...
# Sub-Saharan Africa (IDA & IBRD)             Worried about not having enough money for old ...
# ...

# %%
data.sort_index(inplace=True)

# %%
data
# Out:
#                                                     Series Name  \
# Country Name
# Afghanistan   A woman can open a bank account in the same wa...
# Afghanistan   Women who own a house both alone and jointly (...
# Afghanistan   Men who own a house both alone and jointly (% ...
# Afghanistan   Reason for not using their inactive account: b...
# Afghanistan   Men who own a house both alone and jointly (% ...
# ...                                                         ...
# Zimbabwe      Women who own land jointly (% of women age 15-...
# Zimbabwe                Owns a debit or credit card (% age 15+)
# Zimbabwe      Experience or continue to experience severe fi...
# Zimbabwe      Use a mobile money account two or more times a...
# Zimbabwe      Men who own land both alone and jointly (% of ...
#
#                        Series Code Country Code 2022 [YR2022]
# Country Name
# Afghanistan         SG.OPN.BANK.EQ          AFG             1
# ...

# %%
data.loc['Afghanistan'].head(15)
# Out:
#                                                     Series Name  \
# Country Name
# Afghanistan   A woman can open a bank account in the same wa...
# Afghanistan   Women who own a house both alone and jointly (...
# Afghanistan   Men who own a house both alone and jointly (% ...
# Afghanistan   Reason for not using their inactive account: b...
# Afghanistan   Men who own a house both alone and jointly (% ...
# Afghanistan   Women who own a house both alone and jointly (...
# Afghanistan   Men who own a house both alone and jointly (% ...
# Afghanistan   Women who own a house both alone and jointly (...
# Afghanistan   Reason for not using their inactive account: d...
# Afghanistan   Worried about not having enough money for old ...
# Afghanistan   Men who own a house both alone and jointly (% ...
# Afghanistan   Men who own a house alone (% of men): Q5 (high...
# Afghanistan   Women who own a house both alone and jointly (...
# ...

# %%
data.iloc[50]
# Out:
# Series Name      Men who own a house jointly (% of men)
# Series Code                           SG.OWN.HSJT.MA.ZS
# Country Code                                        AFG
# 2022 [YR2022]                                        ..
# Name: Afghanistan, dtype: object

# %%
data ['Series Code'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='Series Code'>

# %%
import seaborn as sns

# %%
data.head(10)
# Out:
#                                                     Series Name  \
# Country Name
# Afghanistan   A woman can open a bank account in the same wa...
# Afghanistan   Women who own a house both alone and jointly (...
# Afghanistan   Men who own a house both alone and jointly (% ...
# Afghanistan   Reason for not using their inactive account: b...
# Afghanistan   Men who own a house both alone and jointly (% ...
# Afghanistan   Women who own a house both alone and jointly (...
# Afghanistan   Men who own a house both alone and jointly (% ...
# Afghanistan   Women who own a house both alone and jointly (...
# Afghanistan   Reason for not using their inactive account: d...
# Afghanistan   Worried about not having enough money for old ...
#
#                        Series Code Country Code 2022 [YR2022]
# Country Name
# Afghanistan         SG.OPN.BANK.EQ          AFG             1
# Afghanistan   SG.OWN.HSAJ.FE.Q1.ZS          AFG            ..
# ...

# %%
data ['2022 [YR2022]'].value_counts().plot(kind='pie',figsize=(15,15))
# Out:
# <Axes: ylabel='count'>
